# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

# %%
browser = webdriver.Chrome()

# %%
df = pd.read_csv('D:\data cleaning\datasets\gfg-yt by me\gfg-yt.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\bhave\AppData\Local\Temp\ipykernel_34928\523655209.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('D:\data cleaning\datasets\gfg-yt by me\gfg-yt.csv')
#                                                   title  \
# 0     All About NIMCET | How To Do MCA From Top NIT'...
# 1     What To Do In College 3rd Year? | B.Tech 3rd Y...
# 2     Crack Any System Design Interview with This 4-...
# 3               JavaScript explained in just 7 Minutes!
# 4     Nation Skill Up | GeeksforGeeks | #skillupwithgfg
# ...                                                 ...
# 2030  Length of shortest chain to reach a target wor...
# 2031                          Binary Search | GeeksQuiz
# 2032  Number of Triangles in an Undirected Graph | G...
# 2033  Write a program to print all permutations of a...
# 2034  Longest Span with same Sum in two Binary array...
#
# ...

# %%
data = []
for link in df['video_link']:
    browser.get(link)
    time.sleep(5)
    sp = BeautifulSoup(browser.page_source,'html.parser')
    try:
        title = sp.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[0].text
    except:
        title = np.nan
    try:
        view = sp.find('span' , class_ = 'view-count style-scope ytd-video-view-count-renderer').text
    except:
        view = np.nan
    try:
        date = sp.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[1].text
    except:
        date = np.nan
    try:
        like = soup.find('yt-formatted-string', class_ = 'style-scope ytd-toggle-button-renderer style-text').text
    except:
        like = np.nan  
    try:
        description = soup.find('yt-formatted-string', class_ = 'content style-scope ytd-video-secondary-info-renderer').text
    except:
        description = np.nan
    print(title,'|',)
    data.append([title , date, like, view, link, description])
# Out:
# All About NIMCET | How To Do MCA From Top NIT's? | Exam Pattern | Syllabus | Cutoff | Resources |
# What To Do In College 3rd Year? | B.Tech 3rd Year Complete Roadmap |
# Crack Any System Design Interview with This 4-Step Framework! 🚀 |
# JavaScript explained in just 7 Minutes! |
# Nation Skill Up | GeeksforGeeks | #skillupwithgfg |
# How To Start Coding In 2025 & 2026 | Complete Roadmap For Beginners 🚀 |
# How to never fail a technical interview |
# Get ready to #skillupwithgfg |
# Crack GATE 2026 with This Strategy | Deep Prep, Smart Revision & GfG Tools! 🚀📚 |
# DSA Free Course | Dynamic Programming In One Shot | DSA | DP In One Shot |
# I Investigated Tech Layoffs in 2025 |
# The Harsh Truth About Off-Campus Placements 😓 |
# How To Become a Scientist In ISRO? | Exam Pattern | CutOff | Syllabus | Step-by-Step Guide |
# Most Asked DSA Questions in Interviews | Crack Any Coding Round |
# The Future of Coding is Here |
# ...

# %%
len(data)
# Out:
# 261

# %%
df = pd.DataFrame(data,columns = ['title','date','like','view','link','description'])
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File D:\anaconda\envs\Visual\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File D:\anaconda\envs\Visual\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
# ...

# %%
df.to_csv('video.csv',index = False)

# %%
date
# Out:
# 'Tayyari Batch Link - https://www.geeksforgeeks.org/courses/placement-prep-programming-data-structures-algorithm\r\n\r\nPre Register for Nation SkillUp -  https://gfgcdn.com/tu/VJ5/'

# %%
sp.find('yt-animated-rolling-number',class_ = 'animated-rolling-number-wiz').text
# Out:
# '\xa012345678901234567890123456789\xa0\xa012345678901234567890123456789\xa0'

# %%
time = sp.find_all('span',class_ = 'yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap')

# %%
time
# Out:
# [<span class="yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap" dir="auto" role="text"><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(255, 255, 255);">Preparing for NIMCET, the gateway to MCA courses in top NITs? In this complete guide, we explain everything about the NIMCET exam — including the exam pattern, detailed syllabus, cut-off trends, top resources, and preparation strategy. Whether you're from a CS/IT background or a non-CS stream, this video will help you</span></span>,
# ...
